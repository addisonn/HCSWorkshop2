# %%
# HCS Workshop 2, Web Scraping
# Scrape Net a Porter bag sections

# %%
# Author: Addison Zhang

# %%
# import packages and background info
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
def scrap_netaporter_bag(t):
    more_pages = True
    prev = "https://www.net-a-porter.com"
    
    page_url = f"https://www.net-a-porter.com/en-us/shop/bags/{t}"
    links = []
    names = []
    prices = []
    brands = []
    while True:
        page = requests.get(page_url)
        if (page.status_code) == 200:
            soup = BeautifulSoup(page.content, 'html.parser')
            products = soup.find("div", {"class": "ProductGrid50 ProductListWithLoadMore50__listingGrid"})
            items = products.find_all('a')

            links = links + [prev + item['href'] for item in items]
            for item in items:
                desc = item.find(class_='ProductItem24__skeletonContainer')
                names.append(desc.find("span", {"itemprop": "name"}).get_text())
                prices.append(desc.find("span", {"itemprop": "price"}).get_text().replace(',', '').replace('$', ''))
                brands.append(desc.find("span", {"itemprop": "brand"}).get_text())
            
            num = page_url[-1]
            page_url = page_url.replace(num, str(int(num) + 1)) if num.isdigit() else page_url + "?pageNumber=2"
        else:
            break

    products_df = pd.DataFrame([names, prices, brands, links], index=['name', 'price', 'brand', 'link']).T
    products_df['price'] = products_df['price'].astype('float')

    return products_df

# %%
bag_types = ["shoulder-bags", "tote-bags", "mini-bags", "backpacks", "clutch-bags", "evening-bags", 
             "luggage-and-travel", "belt-bags", "bucket-bags", "top-handle", "bag-trends"]

bag_type = "top-handle"
results = scrap_netaporter_bag(bag_type)
results
# Out:
#                                                   name   price  \
# 0                   Uptown small textured-leather tote  2290.0
# 1            Puzzle mini textured-leather shoulder bag  1950.0
# 2    Ai Messenger small convertible quilted leather...  1990.0
# 3                Hourglass small textured-leather tote  1850.0
# 4               Eyes small leather-trimmed beaded tote   795.0
# ..                                                 ...     ...
# 202                                       Leather tote  2890.0
# 203                          Bon Bon velvet bucket bag   995.0
# 204                             Flat Circle suede tote   990.0
# 205               Metro medium canvas and leather tote  3390.0
# 206  Valentino Garavani Go Logo Escape small textur...  2245.0
#
#               brand                                               link
# 0     SAINT LAURENT  https://www.net-a-porter.com/en-us/shop/produc...
# 1             Loewe  https://www.net-a-porter.com/en-us/shop/produc...
# 2             Akris  https://www.net-a-porter.com/en-us/shop/produc...
# 3        Balenciaga  https://www.net-a-porter.com/en-us/shop/produc...
# 4    Anya Hindmarch  https://www.net-a-porter.com/en-us/shop/produc...
# ..              ...                                                ...
# 202           Fendi  https://www.net-a-porter.com/en-us/shop/produc...
# 203      Jimmy Choo  https://www.net-a-porter.com/en-us/shop/produc...
# 204         The Row  https://www.net-a-porter.com/en-us/shop/produc...
# 205        TOM FORD  https://www.net-a-porter.com/en-us/shop/produc...
# 206       Valentino  https://www.net-a-porter.com/en-us/shop/produc...
#
# [207 rows x 4 columns]

# %%
results.sort_values(by=['price', 'brand'], ascending=[False, True])
# Out:
#                                       name   price            brand  \
# 182   Cabas large intrecciato leather tote  7500.0   Bottega Veneta
# 173  Cabas medium intrecciato leather tote  7000.0   Bottega Veneta
# 190  Cabas medium intrecciato leather tote  7000.0   Bottega Veneta
# 200            Leather-trimmed python tote  4600.0            Fendi
# 148    Garance medium studded leather tote  4360.0            Alaïa
# ..                                     ...     ...              ...
# 50     + Palorosa small striped woven tote   290.0             Eres
# 43      Play Mini croc-effect leather tote   290.0            Gu_de
# 68         Bobby mini buckled leather tote   270.0             BOYY
# 57                         Eos rattan tote   220.0        Cult Gaia
# 142          Lucy padded faux leather tote   190.0  A.W.A.K.E. MODE
#
#                                                   link
# 182  https://www.net-a-porter.com/en-us/shop/produc...
# 173  https://www.net-a-porter.com/en-us/shop/produc...
# 190  https://www.net-a-porter.com/en-us/shop/produc...
# 200  https://www.net-a-porter.com/en-us/shop/produc...
# 148  https://www.net-a-porter.com/en-us/shop/produc...
# ..                                                 ...
# 50   https://www.net-a-porter.com/en-us/shop/produc...
# 43   https://www.net-a-porter.com/en-us/shop/produc...
# 68   https://www.net-a-porter.com/en-us/shop/produc...
# 57   https://www.net-a-porter.com/en-us/shop/produc...
# 142  https://www.net-a-porter.com/en-us/shop/produc...
#
# [207 rows x 4 columns]
